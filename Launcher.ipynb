# %% [markdown]
# # MLP Visualizer
#
# Run the cell below to launch the MLP visualizer right in your browser! Make sure to wait a few seconds after running for the launch button to appear.

# %%
import os
import time
from IPython.display import display, HTML

# Ensure all required visualizer dependencies exist in your DataHub container
os.system("pip install streamlit torch networkx plotly pandas -q")

# Start Streamlit silently in the background
os.system("streamlit run app.py --server.port 8501 --server.enableCORS false --server.headless true &")

# Give it a few seconds to configure the backend
time.sleep(3)

url = "https://datahub.berkeley.edu/user-redirect/proxy/8501/"

button_html = f"""
<a href="{url}" target="_blank" style="
    display: inline-block; 
    padding: 15px 32px; 
    font-size: 20px; 
    font-family: Arial, sans-serif;
    font-weight: bold; 
    color: white; 
    background-color: #003262;
    border-radius: 8px; 
    text-decoration: none;
    box-shadow: 0 4px 6px rgba(0,0,0,0.1);
">Launch MLP Visualizer</a>
"""
display(HTML(button_html))
