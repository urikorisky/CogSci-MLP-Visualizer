# %% [markdown]
# # 🧠 Interactive Neural Network Visualizer
#
# ### How to start:
# 1. **Click the code block directly below this text** so it is highlighted.
# 2. Press **Shift + Enter** on your keyboard, OR click the **Play (▶) button** at the very top of the window.
# 3. A large launch button will appear magically in a few seconds!

# %%
import build_ui
build_ui.launch()
